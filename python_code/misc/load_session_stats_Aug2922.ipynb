# %%
# %reset -f
# %whos
# Out:
# Interactive namespace is empty.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import time, os, sys, pdb
# %matplotlib inline
low_memory=False

path = input("Enter path to session stats file:")
file = input("Enter filename:")

df = pd.read_csv(path + "\\" + file)
# Out:
# Enter path to session stats file: D:\Vickers_McCormick_MESO_METHODS_ppr_Jul1922\Fig_2
# Enter filename: rec_n_time_both_preps_pload.csv

# %%
PlotDir = os.path.join('D:\\Vickers_McCormick_MESO_METHODS_ppr_Jul1922\\Fig_2')

# %%
df
# Out:
#    m_id_csb  n_cell_csb  t_min_csb  res_csb    pix_csb  acq_rate_csb m_id_css  \
# 0      E210      5000.0      30.00      5.0   924000.0          3.06     E210
# 1      E210      3432.0      30.00      5.0   739200.0          2.79     E210
# 2      E210      2850.0      24.50      2.5  2112000.0          1.79     E210
# 3      E210      4981.0      30.00      5.0   924000.0          3.06     E210
# 4      E210      3096.0      20.00      5.0   924000.0          3.06     E210
# 5      E210      6137.0      30.00      5.0   924000.0          3.06     E210
# 6      E210      7188.0      30.00      5.0   924000.0          3.06     E210
# 7      E210      3527.0      56.07      5.0   924000.0          3.06     E210
# 8      E210      2992.0      30.00      5.0   924000.0          3.06     E210
# 9      E210      3525.0      30.00      5.0   924000.0          3.06     E174
# 10     E210      3538.0      30.00      5.0   924000.0          3.06     E174
# ...

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.t_min_csb, df.n_cell_csb, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.t_min_csb)+10)
plt.ylim(0,max(df.n_cell_csb)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.t_min_css, df.n_cell_css, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.t_min_css)+10)
plt.ylim(0,max(df.n_cell_css)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.t_min_latb, df.n_cell_latb, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.t_min_latb)+10)
plt.ylim(0,max(df.n_cell_latb)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.t_min_latb, df.n_cell_latb, marker = "o", s=200, c=colors, alpha=0.5)
plt.xlim(0,max(df.t_min_latb)+10)
plt.ylim(0,max(df.n_cell_latb)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.t_min_lats, df.n_cell_lats, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.t_min_lats)+10)
plt.ylim(0,max(df.n_cell_lats)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.acq_rate_csb, df.pix_csb, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.acq_rate_csb)+1)
plt.ylim(0,max(df.pix_csb)+50000)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.acq_rate_css, df.pix_css, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.acq_rate_css)+1)
plt.ylim(0,max(df.pix_css)+50000)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.acq_rate_latb, df.pix_latb, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.acq_rate_latb)+1)
plt.ylim(0,max(df.pix_latb)+50000)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.acq_rate_lats, df.pix_lats, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.acq_rate_lats)+1)
plt.ylim(0,max(df.pix_lats)+50000)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.res_csb, df.n_cell_csb, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.res_csb)+0.5)
plt.ylim(0,max(df.n_cell_csb)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.res_css, df.n_cell_css, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.res_css)+0.5)
plt.ylim(0,max(df.n_cell_css)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.res_latb, df.n_cell_latb, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.res_latb)+0.5)
plt.ylim(0,max(df.n_cell_latb)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.res_lats, df.n_cell_lats, s=area, c=colors, alpha=0.5)
plt.xlim(0,max(df.res_lats)+0.5)
plt.ylim(0,max(df.n_cell_lats)+500)
plt.show()

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(df.res_lats, df.n_cell_lats, s=area, c=colors, alpha=0.5)
plt.xlim(0,2.5)
plt.ylim(0,2000)
plt.show()

# %%
t_min_csb=df.t_min_csb[0:39]
t_min_latb=df.t_min_latb
t_min_b=np.concatenate((t_min_csb,t_min_latb),axis=0)

n_cell_csb=df.n_cell_csb[0:39]
n_cell_latb=df.n_cell_latb
n_cell_b=np.concatenate((n_cell_csb,n_cell_latb),axis=0)
                        
pix_csb=df.pix_csb[0:39]
pix_latb=df.pix_latb
pix_b=np.concatenate((pix_csb,pix_latb),axis=0)

plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(t_min_b[0:39], (n_cell_b[0:39]/pix_b[0:39])*16,  s=200, c='blue', alpha=0.5)
plt.scatter(t_min_b[39:91], (n_cell_b[39:91]/pix_b[39:91])*16,  s=200, c='red', alpha=0.5)
plt.xlim(0,max(t_min_b)+5)
plt.ylim(0,max(n_cell_b/pix_b)*16+.01)
plt.xticks(fontsize=36,fontweight='bold')
plt.yticks(fontsize=28,fontweight='bold')
#plt.ylabel('neural tiling density',labelpad=10,fontsize=24)
#plt.xlabel('session duration (min)', labelpad=10,fontsize=24)

x = np.mean(t_min_b[0:39])
y = np.mean((n_cell_b[0:39]/pix_b[0:39])*16)
xerr = np.std(t_min_b[0:39])
yerr = np.std((n_cell_b[0:39]/pix_b[0:39])*16)
plt.errorbar(x, y, xerr=[[xerr], [xerr]], yerr=[[yerr], [yerr]],fmt='o',elinewidth=8,capsize=18,capthick=8,color='blue')

x = np.mean(t_min_b[39:91])
y = np.mean((n_cell_b[39:91]/pix_b[39:91])*16)
xerr = np.std(t_min_b[39:91])
yerr = np.std((n_cell_b[39:91]/pix_b[39:91])*16)
plt.errorbar(x, y, xerr=[[xerr], [xerr]], yerr=[[yerr], [yerr]],fmt='o',elinewidth=8,capsize=18,capthick=8,color='red')

plt.savefig(os.path.join(PlotDir,'neural_tiling_density_by_sess_dur_all_big_sess'+'.tif'),dpi=300,format='tif')

# %%
print(t_min_b.shape)
print(n_cell_b)
# Out:
# (91,)
# [5000. 3432. 2850. 4981. 3096. 6137. 7188. 3527. 2992. 3525. 3538. 3560.
#  3100. 2586.  557.  747. 3289. 1233. 1513. 3223. 3273. 2135. 1958. 3147.
#  2943. 3396. 3186. 4399. 3432. 3274. 2418. 4339. 2410. 2967. 2965. 3726.
#  3785. 3747. 3616. 4782. 4782. 4632. 3634. 4764. 4909. 4912. 4717. 4111.
#  3707. 4197. 4150. 4106. 4991. 4987. 4783. 4733. 4910. 4527. 4778. 3617.
#  4027. 4122. 3955. 4358. 4313. 4779. 4937. 3257. 4235. 4074. 4426. 5161.
#  4885. 4337. 7717. 5678. 5183. 3897. 6256. 7438. 7640. 3373. 2582. 4027.
#  3543. 3263. 3649. 3211. 3414. 1971. 3116.]

# %%
t_min_csb=df.t_min_csb
t_min_latb=df.t_min_latb
print(t_min_csb.shape)
t_min_b=np.concatenate((t_min_csb,t_min_latb),axis=0)
print(t_min_b.shape)
# Out:
# (52,)
# (104,)

# %%
plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(1/df.res_lats, ((df.n_cell_lats/df.pix_lats)*(20/df.res_lats)**2),  s=200, c='red', alpha=0.5)
plt.xlim(0.4,max(1/df.res_lats)+.01)
plt.ylim(0,max((df.n_cell_lats/df.pix_lats)*(20/df.res_lats)**2)+.01)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.ylabel('neural tiling density',labelpad=10,fontsize=24)
plt.xlabel('resolution (micrometers / pixel)', labelpad=10,fontsize=24)

x = np.mean(1/df.res_lats)
y = np.mean((df.n_cell_lats/df.pix_lats)*(20/df.res_lats)**2)
xerr = np.std(1/df.res_lats)
yerr = np.std((df.n_cell_lats/df.pix_lats)*(20/df.res_lats)**2)
plt.errorbar(x, y, xerr=[[xerr], [xerr]], yerr=[[yerr], [yerr]],fmt='o',elinewidth=4,capsize=14,capthick=4,color='red')

plt.savefig(os.path.join(PlotDir,'neural_tiling_density_by_resolution_lats'+'.tif'),dpi=300,format='tif')

# %%
plt.rcParams['axes.linewidth'] = 5

res_css=1/df.res_css[0:22]
res_lats=1/df.res_lats[0:33]
res_s=np.concatenate((res_css,res_lats),axis=0)

n_cell_css=df.n_cell_css[0:22]
n_cell_lats=df.n_cell_lats[0:33]
n_cell_s=np.concatenate((n_cell_css,n_cell_lats),axis=0)
                        
pix_css=df.pix_css[0:22]
pix_lats=df.pix_lats[0:33]
pix_s=np.concatenate((pix_css,pix_lats),axis=0)

plt.rcParams["figure.figsize"] =(9,9) 
colors = np.random.rand(52)
area = (30 * np.random.rand(52))**2  # 0 to 15 point radii
plt.scatter(res_s[0:22], ((n_cell_s[0:22]/pix_s[0:22])*(20*res_s[0:22])**2),  s=200, c='blue', alpha=0.5,linewidth=5)
plt.scatter(res_s[22:55], ((n_cell_s[22:55]/pix_s[22:55])*(20*res_s[22:55])**2),  s=200, c='red', alpha=0.5,linewidth=5)
#plt.gca().get_frame().set_linewidth(5)
plt.xlim(0,max(res_s)+0.1)
plt.ylim(0,max((n_cell_s/pix_s)*(20*res_s)**2)+.05)
plt.xticks(fontsize=36,fontweight='bold')
plt.yticks(fontsize=36,fontweight='bold')
#plt.ylabel('neural tiling density',labelpad=10,fontsize=36,fontweight='bold')
#plt.xlabel('resolution (micrometers / pixel)', labelpad=10,fontsize=36,fontweight='bold')

x = np.mean(res_s[0:22])
y = np.mean((n_cell_s[0:22]/pix_s[0:22])*(20*res_s[0:22])**2)
xerr = np.std(res_s[0:22])
yerr = np.std((n_cell_s[0:22]/pix_s[0:22])*(20*res_s[0:22])**2)
plt.errorbar(x, y, xerr=[[xerr], [xerr]], yerr=[[yerr], [yerr]],fmt='o',elinewidth=8,capsize=18,capthick=8,color='blue')

x = np.mean(res_s[22:55])
y = np.mean((n_cell_s[22:55]/pix_s[22:55])*(20*res_s[22:55])**2)
xerr = np.std(res_s[22:55])
yerr = np.std((n_cell_s[22:55]/pix_s[22:55])*(20*res_s[22:55])**2)
plt.errorbar(x, y, xerr=[[xerr], [xerr]], yerr=[[yerr], [yerr]],fmt='o',elinewidth=8,capsize=18,capthick=8,color='red')

plt.savefig(os.path.join(PlotDir,'neural_tiling_density_by_resolution_all_small_sess'+'.tif'),dpi=300,format='tif')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-436-1cb04a6c118b> in <module>
#      22 plt.ylim(0,max((n_cell_s/pix_s)*(20*res_s)**2)+.05)
#      23 plt.xticks(fontsize=36,fontweight='bold')
# ---> 24 plt.get_major_ticks()
#      25 plt.yticks(fontsize=36,fontweight='bold')
#      26 #plt.ylabel('neural tiling density',labelpad=10,fontsize=36,fontweight='bold')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'get_major_ticks'

# %%
import importlib
importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
res_css=1/df.res_css[0:22]
res_lats=1/df.res_lats[0:33]
res_s=np.concatenate((res_css,res_lats),axis=0)
print(res_s.shape)
# Out:
# (55,)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm

x = np.arange(4)

n_cell_csb=df.n_cell_csb.to_numpy()
n_cell_latb=df.n_cell_latb.to_numpy()
n_cell_css=df.n_cell_css.to_numpy()
n_cell_lats=df.n_cell_lats.to_numpy()

D=np.zeros((len(n_cell_csb),4))

D[:,0]=n_cell_csb
D[:,1]=n_cell_latb
D[:,2]=n_cell_css
D[:,3]=n_cell_lats

n_cell_csb_shorter=n_cell_csb.copy()[0:39]
n_cell_css_shorter=n_cell_css.copy()[0:22]
n_cell_lats_shorter=n_cell_lats.copy()[0:33]

#n_cell_csb_short=n_cell_csb[~np.isnan(n_cell_csb)]
#n_cell_latb_short=n_cell_latb[~np.isnan(n_cell_latb)]
n_cell_latb_short=n_cell_latb.copy()
n_cell_dat=[n_cell_csb_shorter,n_cell_latb_short,n_cell_css_shorter,n_cell_lats_shorter]

#n_cell_dat = np.where(np.isfinite(D), D, 0)
scat_0=(np.full(len(n_cell_csb_shorter),1.000))
scat_1=(np.full(len(n_cell_latb_short),2.000))
scat_2=(np.full(len(n_cell_css_shorter),3.000))
scat_3=(np.full(len(n_cell_lats_shorter),4.000))

for i in range(0,len(scat_0)):
    scat_0[i]=scat_0[i]+(np.random.rand(1)-0.5)*(2/12)
for i in range(0,len(scat_1)):
    scat_1[i]=scat_1[i]+(np.random.rand(1)-0.5)*(2/12)
for i in range(0,len(scat_2)):
    scat_2[i]=scat_2[i]+(np.random.rand(1)-0.5)*(2/12)
for i in range(0,len(scat_3)):
    scat_3[i]=scat_3[i]+(np.random.rand(1)-0.5)*(2/12)

plt.rcParams["figure.figsize"] =(12,9)     

plt.boxplot(n_cell_dat,widths=(0.75, 0.75, 0.75, 0.75),showfliers=False)
plt.errorbar(x[0]+1, np.mean(n_cell_dat[0], axis=0), yerr=np.std(n_cell_dat[0], axis=0))
plt.errorbar(x[1]+1, np.mean(n_cell_dat[1], axis=0), yerr=np.std(n_cell_dat[1], axis=0))
plt.errorbar(x[2]+1, np.mean(n_cell_dat[2], axis=0), yerr=np.std(n_cell_dat[2], axis=0))
plt.errorbar(x[3]+1, np.mean(n_cell_dat[3], axis=0), yerr=np.std(n_cell_dat[3], axis=0))
plt.scatter(scat_0, n_cell_csb_shorter, s=200, color='blue',alpha=0.4)
plt.scatter(scat_1, n_cell_latb_short, s=200, color='red',alpha=0.4)
plt.scatter(scat_2, n_cell_css_shorter, s=200, color='blue',alpha=0.4)
plt.scatter(scat_3, n_cell_lats_shorter, s=200, color='red',alpha=0.4)
plt.xlim(0.5,4.5)
ymax=max(n_cell_csb_shorter)
if max(n_cell_latb_short)>ymax:
    ymax=max(n_cell_latb_short)
plt.ylim(0,ymax+500)
#plt.xticks([1,2,3,4],['cSkull big','A1V1M2 big', 'cSkull small', 'A1V1M2 small'],fontsize=36,fontweight='bold')
plt.xticks([1,2,3,4],['','', '', ''],fontsize=36,fontweight='bold')
plt.yticks([0,1000,2000,3000,4000,5000,6000,7000,8000],[0,'',2000,'',4000,'',6000,'',8000], fontsize=36,fontweight='bold')
#plt.ylabel('number of neurons',labelpad=20,fontsize=24)
#plt.title('summary, all mesoscope sessions',fontsize=24)

plt.savefig(os.path.join(PlotDir,'summary_ncells_session_type'+'.tif'),dpi=300,format='tif')

# %%
#redo box plot with ax

import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm

x = np.arange(2)

n_cell_csb=df.n_cell_csb.to_numpy()
n_cell_latb=df.n_cell_latb.to_numpy()

D=np.zeros((len(n_cell_csb),2))

D[:,0]=n_cell_csb
D[:,1]=n_cell_latb

n_cell_csb_shorter=n_cell_csb_short.copy()[0:39]
#n_cell_csb_short=n_cell_csb[~np.isnan(n_cell_csb)]
#n_cell_latb_short=n_cell_latb[~np.isnan(n_cell_latb)]
n_cell_latb_short=n_cell_latb.copy()
n_cell_dat=[n_cell_csb_shorter,n_cell_latb_short]

#n_cell_dat = np.where(np.isfinite(D), D, 0)
scat_0=(np.full(len(n_cell_csb_shorter),1.000))
scat_1=(np.full(len(n_cell_latb_short),2.000))

for i in range(0,len(scat_0)):
    scat_0[i]=scat_0[i]+(np.random.rand(1)-0.5)*(2/12)
for i in range(0,len(scat_1)):
    scat_1[i]=scat_1[i]+(np.random.rand(1)-0.5)*(2/12)

plt.rcParams["figure.figsize"] =(6,9)     

plt.boxplot(n_cell_dat,widths=(0.75, 0.75))
plt.errorbar(x[0]+1, np.mean(n_cell_dat[0], axis=0), yerr=np.std(n_cell_dat[0], axis=0))
plt.errorbar(x[1]+1, np.mean(n_cell_dat[1], axis=0), yerr=np.std(n_cell_dat[1], axis=0))
plt.scatter(scat_0, n_cell_csb_shorter, alpha=0.4)
plt.scatter(scat_1, n_cell_latb_short, alpha=0.4)
plt.xlim(0.5,2.5)
ymax=max(n_cell_csb_shorter)
if max(n_cell_latb_short)>ymax:
    ymax=max(n_cell_latb_short)
plt.ylim(0,ymax)

# %%
print(max(D[0,:]))
print(max(D[1,:]))
# Out:
# 5000.0
# 4782.0

# %%
n_cell_csb=df.n_cell_csb.to_numpy()
n_cell_latb=df.n_cell_latb.to_numpy()
D=np.concatenate((n_cell_csb.T,n_cell_latb.T))
print(n_cell_csb.shape)
print(n_cell_csb.shape)
print(D.shape)

D=np.zeros((len(n_cell_csb),2))
# Out:
# (52,)
# (52,)
# (104,)

# %%
n_cell_csb_short
# Out:
# array([5000., 3432., 2850., 4981., 3096., 6137., 7188., 3527., 2992.,
#        3525., 3538., 3560., 3100., 2586.,  557.,  747., 3289., 1233.,
#        1513., 3223., 3273., 2135., 1958., 3147., 2943., 3396., 3186.,
#        4399., 3432., 3274., 2418., 4339., 2410., 2967., 2965., 3726.,
#        3785., 3747., 3616.])

# %%
D[:,0]=n_cell_csb
D[:,1]=n_cell_latb
print(D)
# Out:
# [[5000. 4782.]
#  [3432. 4782.]
#  [2850. 4632.]
#  [4981. 3634.]
#  [3096. 4764.]
#  [6137. 4909.]
#  [7188. 4912.]
#  [3527. 4717.]
#  [2992. 4111.]
#  [3525. 3707.]
#  [3538. 4197.]
#  [3560. 4150.]
#  [3100. 4106.]
#  [2586. 4991.]
#  [ 557. 4987.]
#  [ 747. 4783.]
#  [3289. 4733.]
#  [1233. 4910.]
#  [1513. 4527.]
#  [3223. 4778.]
#  [3273. 3617.]
#  [2135. 4027.]
#  [1958. 4122.]
#  [3147. 3955.]
#  [2943. 4358.]
#  [3396. 4313.]
#  [3186. 4779.]
#  [4399. 4937.]
#  [3432. 3257.]
#  [3274. 4235.]
#  [2418. 4074.]
#  [4339. 4426.]
#  [2410. 5161.]
#  [2967. 4885.]
#  [2965. 4337.]
#  [3726. 7717.]
#  [3785. 5678.]
#  [3747. 5183.]
#  [3616. 3897.]
#  [  nan 6256.]
#  [  nan 7438.]
#  [  nan 7640.]
#  [  nan 3373.]
#  [  nan 2582.]
#  [  nan 4027.]
#  [  nan 3543.]
#  [  nan 3263.]
#  [  nan 3649.]
#  [  nan 3211.]
#  [  nan 3414.]
#  [  nan 1971.]
#  [  nan 3116.]]

# %%
print(D.shape)
# Out:
# (52, 2)
