# %%
# %reset
# %whos

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
from datetime import datetime
import csv

# %matplotlib inline

path=input("Enter the path to CCF map:")

template_volume = np.load(path + '/template_volume_10um.npy', allow_pickle=True)
annotation_volume = np.load(path + '/annotation_volume_10um_by_index.npy', allow_pickle=True)

with open(path + '/structure_tree_safe_2017.csv', newline='') as csvfile:
    #structurereader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    #for row in structurereader:
    #    print(', '.join(row))
    structure_tree_safe_2017 = list(csv.reader(csvfile))

with open(path + '/structure_tree_safe.csv', newline='') as csvfile:
    #structurereader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    #for row in structurereader:
    #    print(', '.join(row))
    structure_tree_safe = list(csv.reader(csvfile))

structure_tree_safe_2017_frame = pd.read_csv(path + '/structure_tree_safe_2017.csv') 
structure_tree_safe_2017 = pd.read_csv(path + '/structure_tree_safe.csv')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
# Interactive namespace is empty.
# Enter the path to CCF map: C:\Users\McCormick Lab\Documents\Python\meso_stable_versions\cortexLab_python_maps
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4561d22ff5f0> in <module>
#      17 annotation_volume = np.load(path + '/annotation_volume_10um_by_index.npy', allow_pickle=True)
#      18
# ---> 19 template_volume_frame=pd.DataFrame(template_volume)
#      20 annotation_volume_frame=pd.DataFrame(annotation_volume)
#      21
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
# ...

# %%
template_volume.shape
# Out:
# (1320, 800, 1140)

# %%
annotation_volume.shape
# Out:
# (1320, 800, 1140)

# %%
annotation_volume[0,0,0]
# Out:
# 1

# %%
annotation_volume[:-50,4,4]
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=uint16)

# %%
structure_tree_safe_2017_frame
# Out:
#              id  atlas_id                           name acronym  st_level  \
# 0           997      -1.0                           root    root       NaN
# 1             8       0.0  Basic cell groups and regions    grey       NaN
# 2           567      70.0                       Cerebrum      CH       NaN
# 3           688      85.0                Cerebral cortex     CTX       NaN
# 4           695      86.0                 Cortical plate   CTXpl       NaN
# ...         ...       ...                            ...     ...       ...
# 1322         49     713.0     intraparafloccular fissure     ipf       NaN
# 1323         57     714.0              paramedian sulcus     pms       NaN
# 1324         65     715.0           parafloccular sulcus     pfs       NaN
# 1325        624     926.0          Interpeduncular fossa     IPF       NaN
# 1326  304325711       NaN                         retina  retina       NaN
#
# ...

# %%
plt.plot(template_volume[:,:,100])
